# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import numpy as np


data1 = pd.read_csv('10_ul_per_min_exposure_time_15_ms_gain_5_big_concetration_of_capsules_in_suspension_submicron.csv')
data1.set_index("times", inplace=True)

data2 = pd.read_csv('20_ul_per_min_exposure_time_15_ms_gain_5_big_concentration_of_capsules_in_suspension_submicron_before_mag.csv')
data2.set_index("times", inplace=True)

data3 = pd.read_csv('30_ul_per_min_exposure_time_15_ms_gain_5_big_concentration_of_capsules_in_suspension_submicron_before_mag.csv')
data3.set_index("times", inplace=True)

data4 = pd.read_csv('50_ul_per_min_exposure_time_15_ms_gain_5_big_concentration_of_capsules_in_suspension_submicron_before_mag.csv')
data4.set_index("times", inplace=True)

data5 = pd.read_csv('100_ul_per_min_exposure_time_5_ms_gain_5_big_concentration_of_capsules_in_suspension.csv')
data5.set_index("times", inplace=True)

data6 = pd.read_csv('caps_PBS_10_uL_per_min.txt',sep='\t')
data6.set_index("t, sec", inplace=True)

data7 = pd.read_csv('caps_PBS_20_uL_per_min.txt',sep='\t')
data7.set_index("t, sec", inplace=True)

data8 = pd.read_csv('caps_PBS_30_uL_per_min.txt', sep='\t')
data8.set_index("t, sec", inplace=True)

data9 = pd.read_csv('caps_PBS_50_uL_per_min.txt',sep='\t')
data9.set_index("t, sec", inplace=True)

data10 = pd.read_csv('caps_PBS_100_uL_per_min.txt',sep='\t')
data10.set_index("t, sec", inplace=True)

# %%
matplotlib.rcParams.update({'font.size': 10, 'axes.linewidth':0.3, 'xtick.major.size':2,'xtick.major.width':0.3,
                            'ytick.major.size':2,'ytick.major.width':0.3,'xtick.labelsize':10, 'ytick.labelsize':10,
                            'axes.labelsize': 10})
fig = plt.figure(figsize=(7.08661,2.5), dpi = 600)

plt.subplot(253)
x=12/60.*np.arange(len(data8))/35.18
plt.plot(x,np.array(data8), lw = 0.5)
#plt.ylabel(u'Intensity, a.u.', size = 5)
plt.title(r'30 $\mathrm{\mu}$L/min', size = 5)
#plt.grid(axis='both', ls=':')
plt.yticks([])
plt.xticks([])
plt.axvline(x=12/60.*5.7, color='gray', ls='--', linewidth = 0.5)
plt.axvline(x=12/60.*15.82, color='gray', ls='--', linewidth = 0.5)
plt.text(s=u'magnet in',x=12/60.*5.6,y=135,rotation=90,ha='right',va='center', size = 5)
plt.text(s=u'magnet out',x=12/60.*15.92,y=135,rotation=90,ha='left',va='center', size = 5)
plt.ylim(0, 200)
plt.xlim(-0.2, 5.5)

plt.subplot(251)
x=12/60.*np.arange(len(data6))/35.18
plt.plot(x,np.array(data6), lw = 0.5)
plt.ylabel(u'Intensity, a.u.', size = 5)
plt.title(u'10 $\mathrm{\mu}$L/min', size = 5)
#plt.grid(axis='both', ls=':')
plt.xticks([])
plt.yticks(ticks = np.arange(0, 200, step = 25), size = 5)
plt.axvline(x=12/60.*5.3, color='gray', ls='--', linewidth = 0.5)
plt.axvline(x=12/60.*15.5, color='gray', ls='--', linewidth = 0.5)
plt.text(s=u'magnet in',x=12/60.*5.2,y=135,rotation=90,ha='right',va='center', size = 5)
plt.text(s=u'magnet out',x=12/60.*15.6,y=135,rotation=90,ha='left',va='center', size = 5)
plt.ylim(0,200)
plt.xlim(-0.2, 5.5)

plt.subplot(252)
x=12/60.*np.arange(len(data7))/35.18
plt.plot(x,np.array(data7), lw = 0.5)
#plt.ylabel(u'Intensity, a.u.', size = 5)
plt.title(u'20 $\mathrm{\mu}$L/min', size = 5)
##plt.grid(axis='both', ls=':')
plt.yticks([])
plt.xticks([])
plt.axvline(x=12/60.*5.7, color='gray', ls='--', linewidth = 0.5)
plt.axvline(x=12/60.*15., color='gray', ls='--', linewidth = 0.5)
plt.text(s=u'magnet in',x=12/60.*5.6,y=135,rotation=90,ha='right',va='center', size = 5)
plt.text(s=u'magnet out',x=12/60.*15.1,y=135,rotation=90,ha='left',va='center', size = 5)
plt.ylim(0,200)
plt.xlim(-0.2, 5.5)

plt.subplot(254)
x=12/60.*np.arange(len(data9))/35.18
plt.plot(x,np.array(data9), lw = 0.5)
#plt.ylabel(u'Intensity, a.u.', size = 5)
plt.title(u'50 $\mathrm{\mu}$L/min', size = 5)
##plt.grid(axis='both', ls=':')
plt.yticks([])
plt.xticks([])
plt.axvline(x=12/60.*6.9, color='gray', ls='--', linewidth = 0.5)
plt.axvline(x=12/60.*16.75, color='gray', ls='--', linewidth = 0.5)
plt.text(s=u'magnet in',x=12/60.*6.8,y=135,rotation=90,ha='right',va='center', size = 5)
plt.text(s=u'magnet out',x=12/60.*16.85,y=135,rotation=90,ha='left',va='center', size = 5)
plt.ylim(0,200)
plt.xlim(-0.2, 5.5)

plt.subplot(255)
x=12/60.*np.arange(len(data10))/35.18
plt.plot(x,np.array(data10), lw = 0.5)
#plt.ylabel(u'Intensity, a.u.', size = 5)
plt.title(u'100 $\mathrm{\mu}$L/min', size = 5)
##plt.grid(axis='both', ls=':')
plt.yticks([])
plt.xticks([])
plt.axvline(x=12/60.*6, color='gray', ls='--', linewidth = 0.5)
plt.axvline(x=12/60.*16.2, color='gray', ls='--', linewidth = 0.5)
plt.text(s=u'magnet in',x=12/60.*5.9,y=135,rotation=90,ha='right',va='center', size = 5)
plt.text(s=u'magnet out',x=12/60.*16.3,y=135,rotation=90,ha='left',va='center', size = 5)
plt.ylim(0,200)
plt.xlim(-0.2, 5.5)




ax2 = plt.subplot(257)
x=12/60.*np.arange(len(data2))/35.18
plt.plot(x, data2, linewidth = 0.5)
plt.xlabel('Time, min', size = 5)
##plt.grid(axis='both', ls=':', linewidth = 0.3)
plt.xticks([0, 1, 2, 3, 4, 5], size = 5)
plt.yticks([])#ticks = np.arange(0,3500, step = 500), labels = np.arange(0,3.5, step = 0.5), size = 5)
plt.axvline(x = 12/60.*5.7, color='grey', ls='--', linewidth = 0.5)
plt.axvline(x = 12/60.*15., color='grey', ls='--', linewidth = 0.5)
plt.text(s=u'magnet in', x = 12/60.*5.6, y=2300, rotation=90, ha='right',va='center', size = 5)
plt.text(s=u'magnet out', x = 12/60.*15.1, y=2300, rotation=90, ha='left',va='center', size = 5)
plt.ylim(-100, 3500)
plt.xlim(-0.2, 5.5)

ax1 = plt.subplot(256)
x=12/60.*np.arange(len(data1))/35.18
plt.plot(x, data1, linewidth = 0.5)
plt.xlabel('Time, min', size = 5)
plt.ylabel('Number of particles, $10^3$', size = 5)
##plt.grid(axis='both', ls=':', linewidth = 0.3)
plt.xticks([0, 1, 2, 3, 4, 5], size = 5)
plt.yticks(ticks = np.arange(0,3500, step = 500), labels = np.arange(0,3.5, step = 0.5), size = 5)
plt.axvline(x = 12/60.*5.3, color='grey', ls='--', linewidth = 0.5)
plt.axvline(x = 12/60.*15.5, color='grey', ls='--', linewidth = 0.5)
plt.text(s=u'magnet in', x = 12/60.*5.2, y=2300, rotation=90, ha='right',va='center', size = 5)
plt.text(s=u'magnet out', x = 12/60.*15.6, y=2300, rotation=90, ha='left',va='center', size = 5)
plt.ylim(-100, 3500)
plt.xlim(-0.2, 5.5)


ax3 = plt.subplot(258)
x=12/60.*np.arange(len(data3))/35.18
plt.plot(x, data3, linewidth = 0.5)
plt.xlabel('Time, min', size = 5)
##plt.grid(axis='both', ls=':', linewidth  = 0.3)
plt.xticks([0, 1, 2, 3, 4, 5], size = 5)
plt.yticks([])#ticks = np.arange(0,3500, step = 500), labels = np.arange(0,3.5, step = 0.5), size = 5)
plt.axvline(x = 12/60.*5.7, color='grey', ls='--', linewidth = 0.5)
plt.axvline(x = 12/60.*15.82, color='grey', ls='--', linewidth = 0.5)
plt.text(s=u'magnet in', x = 12/60.*5.6, y=2300, rotation=90, ha='right',va='center', size = 5)
plt.text(s=u'magnet out', x = 12/60.*15.92, y=2300, rotation=90, ha='left',va='center', size = 5)
plt.ylim(-100, 3500)
plt.xlim(-0.2, 5.5)

ax4 = plt.subplot(259)
x=12/60.*np.arange(len(data4))/35.18
plt.plot(x, data4, linewidth = 0.5)
plt.xlabel('Time, min', size = 5)
##plt.grid(axis='both', ls=':', linewidth = 0.3)
plt.xticks([0, 1, 2, 3, 4, 5], size = 5)
plt.yticks([])#ticks = np.arange(0,3500, step = 500), labels = np.arange(0,3.5, step = 0.5), size = 5)
plt.axvline(x = 12/60.*6.9, color='grey', ls='--', linewidth = 0.5)
plt.axvline(x = 12/60.*16.75, color='grey', ls='--', linewidth = 0.5)
plt.text(s=u'magnet in', x = 12/60.*6.8, y=2300, rotation=90, ha='right',va='center', size = 5)
plt.text(s=u'magnet out', x = 12/60.*16.85, y=2300, rotation=90, ha='left',va='center', size = 5)
plt.ylim(-100, 3500)
plt.xlim(-0.2, 5.5)

ax5 = plt.subplot(2,5,10)
x=12/60.*np.arange(len(data5))/35.18
plt.plot(x, data5, linewidth = 0.5)
plt.xlabel('Time, min', size = 5)
##plt.grid(axis='both', ls=':', linewidth = 0.3)
plt.xticks([0, 1, 2, 3, 4, 5], size = 5)
plt.yticks([])#ticks = np.arange(0,3500, step = 500), labels = np.arange(0,3.5, step = 0.5), size = 5)
plt.axvline(x = 12/60.*6, color='grey', ls='--', linewidth = 0.5)
plt.axvline(x = 12/60.*16.2, color='grey', ls='--', linewidth = 0.5)
plt.text(s=u'magnet in', x = 12/60.*5.9, y=2300, rotation=90, ha='right',va='center', size = 5)
plt.text(s=u'magnet out', x = 12/60.*16.3, y=2300, rotation=90, ha='left',va='center', size = 5)
plt.ylim(-100, 3500)
plt.xlim(-0.2, 5.5)

plt.subplots_adjust(wspace=0.1, hspace=0.1)
plt.savefig('Figure 3.pdf', dpi=600, bbox_inches='tight')
plt.show()
